# %% [markdown]
# <a href="https://colab.research.google.com/github/NourShehab/nlp-project/blob/main/NLP_MS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # For vector operations
import pandas as pd #To handle the dataframe
import matplotlib.pyplot as plt # To display/plot the results and analysis
import re #regular expression to help clean the text
import random
import seaborn as sns

# Importing all classical models from SKlearn which contains all the models predefined
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
import sklearn.metrics

import nltk

from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import *

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv("/content/drive/MyDrive/NLP/data/spotify_songs.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# Data Preperation and Cleaning

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  object
#  1   song    57650 non-null  object
#  2   link    57650 non-null  object
#  3   text    57650 non-null  object
# dtypes: object(4)
# memory usage: 1.8+ MB

# %%
df.describe(include='all')
# Out:
#               artist                                    song  \
# count          57650                                   57650
# unique           643                                   44824
# top     Donna Summer  Have Yourself A Merry Little Christmas
# freq             191                                      35
#
#                                               link  \
# count                                        57650
# unique                                       57650
# top     /a/abba/ahes+my+kind+of+girl_20598417.html
# freq                                             1
#
#                                                      text
# count                                               57650
# unique                                              57494
# top     I just came back from a lovely trip along the ...
# freq                                                    6

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df=df.rename(columns={'text':'lyrics'})

# %%
df=df.dropna().drop_duplicates()

# %%
df= df.drop(['link'], axis=1)

# %%
df= df.drop(['song'], axis=1)

# %%
df.head()
# Out:
#   artist                                             lyrics
# 0   ABBA  Look at her face, it's a wonderful face  \nAnd...
# 1   ABBA  Take it easy with me, please  \nTouch me gentl...
# 2   ABBA  I'll never know why I had to go  \nWhy I had t...
# 3   ABBA  Making somebody happy is a question of give an...
# 4   ABBA  Making somebody happy is a question of give an...

# %%
df.describe(include='all')
# Out:
#               artist                                             lyrics
# count          57650                                              57650
# unique           643                                              57494
# top     Donna Summer  I just came back from a lovely trip along the ...
# freq             191                                                  6

# %%
artist_counts = df['artist'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=artist_counts.index, y=artist_counts.values)
plt.xlabel('Artist')
plt.ylabel('Number of Songs')
plt.title('Number of Songs by Artist')
plt.xticks(rotation=90)
plt.show()

# %%
artist_counts = df['artist'].value_counts().tail(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=artist_counts.index, y=artist_counts.values)
plt.xlabel('Artist')
plt.ylabel('Number of Songs')
plt.title('Number of Songs by Artist')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Cleaning

# %%
brief_cleaning= (re.sub("[^A-Za-z']+", ' ',str(row)).lower() for row in df['lyrics'])
df_tmp=pd.DataFrame({'clean':brief_cleaning})
df['lyrics']=df_tmp['clean']
df['lyrics'] = df['lyrics'].str.replace(r'[^\w\s]+', '')
df['lyrics'] = df['lyrics'].str.replace('chorus', ' ', regex=False)
df['lyrics'] = df['lyrics'].str.replace('verse', '', regex=True)
df['lyrics'] = df['lyrics'].str.replace('intro', '', regex=True)
df['lyrics'] = df['lyrics'].str.replace('original', '', regex=True)
df['lyrics'] = df['lyrics'].str.replace('outro', '', regex=True)
df['lyrics'] = df['lyrics'].astype(str)
df['lyrics'] = df['lyrics'].str.replace(r'[^a-zA-Z\s]+', '', regex=True)
df['lyrics'] = [i.lower().replace("\n", "") for i in df['lyrics']]
df['artist']=[i.lower().replace("\n","") for i in df['artist']]
df.head()
# Out:
#   artist                                             lyrics
# 0   abba  look at her face its a wonderful face and it m...
# 1   abba  take it easy with me please touch me gently li...
# 2   abba  ill never know why i had to go why i had to pu...
# 3   abba  making somebody happy is a question of give an...
# 4   abba  making somebody happy is a question of give an...

# %% [markdown]
# Tf-idf

# %%
tmp=df[["artist","lyrics"]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer


tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(tmp['lyrics'])
count_vectorizer = CountVectorizer()
count_matrix = count_vectorizer.fit_transform(tmp['lyrics'])

def wordList_removeStopWords(artist_text):
    stop = stopwords.words('english') + ['\n']
    wordList = []
    for word in word_tokenize(artist_text.lower().strip()):
        if not word in stop:
            wordList= ' '.join([word])
    return wordList


artist_most_frequent_words = {}
for artist, group in tmp.groupby('artist'):
    artist_text = ' '.join(group['lyrics'])

    words_without_stopwords = wordList_removeStopWords(artist_text)

    artist_tfidf_matrix = tfidf_vectorizer.transform([words_without_stopwords])
    max_tfidf_index = artist_tfidf_matrix.argmax()
    #most_frequent_word = tfidf_vectorizer.get_feature_names()[max_tfidf_index]
    most_frequent_word = count_vectorizer.get_feature_names_out()[max_tfidf_index]
    artist_most_frequent_words[artist] = most_frequent_word
artist_most_frequent_words
# Out:
# {"'n sync": 'love',
#  'abba': 'aha',
#  'ace of base': 'anyway',
#  'adam sandler': 'back',
#  'adele': 'young',
#  'aerosmith': 'thighs',
#  'air supply': 'pass',
#  'aiza seguerra': 'aa',
#  'alabama': 'everywhere',
#  'alan parsons project': 'home',
#  'aled jones': 'raise',
#  'alice cooper': 'aah',
#  'alice in chains': 'say',
#  'alison krauss': 'one',
#  'allman brothers band': 'yeah',
#  'alphaville': 'chains',
#  'america': 'friend',
#  'amy grant': 'round',
#  'andrea bocelli': 'white',
#  'andy williams': 'seen',
#  'annie': 'long',
#  'ariana grande': 'shawty',
#  'ariel rivera': 'met',
#  'arlo guthrie': 'life',
#  'arrogant worms': 'buffet',
#  'avril lavigne': 'go',
#  'backstreet boys': 'love',
#  'barbie': 'yeah',
#  'barbra streisand': 'life',
#  'beach boys': 'joshin',
#  'beautiful south': 'meat',
#  'beauty and the beast': 'beast',
#  'bee gees': 'woman',
#  'bette midler': 'wings',
#  'bill withers': 'round',
#  'billie holiday': 'remember',
#  'billy joel': 'ill',
#  'bing crosby': 'arrested',
#  'black sabbath': 'feel',
#  'blur': 'love',
#  'bob dylan': 'blue',
#  'bob marley': 'game',
#  'bob rivers': 'day',
#  'bob seger': 'accompny',
#  'bon jovi': 'way',
#  'boney m.': 'white',
#  'bonnie raitt': 'comin',
#  'bosson': 'meant',
#  'bread': 'awhile',
#  'britney spears': 'loved',
#  'bruce springsteen': 'move',
#  'bruno mars': 'back',
#  'bryan white': 'beautiful',
#  'cake': 'head',
#  'carly simon': 'hour',
#  'carol banawa': 'lifes',
#  'carpenters': 'love',
#  'cat stevens': 'girl',
#  'celine dion': 'follow',
#  'chaka khan': 'love',
#  'cheap trick': 'want',
#  'cher': 'fade',
#  'chicago': 'aa',
#  'children': 'everywhere',
#  'chris brown': 'lisa',
#  'chris rea': 'hell',
#  'christina aguilera': 'shut',
#  'christina perri': 'forgive',
#  'christmas songs': 'go',
#  'christy moore': 'jar',
#  'chuck berry': 'four',
#  'cinderella': 'feet',
#  'clash': 'boyo',
#  'cliff richard': 'love',
#  'coldplay': 'wears',
#  'cole porter': 'led',
#  'conway twitty': 'hollow',
#  'counting crows': 'count',
#  'creedence clearwater revival': 'aa',
#  'crowded house': 'die',
#  'culture club': 'charity',
#  'cyndi lauper': 'hold',
#  'dan fogelberg': 'sunrise',
#  'dave matthews band': 'say',
#  'david allan coe': 'girl',
#  'david bowie': 'dancing',
#  'david guetta': 'enough',
#  'david pomeranz': 'admiration',
#  'dean martin': 'need',
#  'death': 'ritual',
#  'deep purple': 'ah',
#  'def leppard': 'guitar',
#  'demi lovato': 'yeah',
#  'depeche mode': 'wrong',
#  'devo': 'right',
#  'dewa 19': 'one',
#  'diana ross': 'place',
#  'dire straits': 'end',
#  'divine': 'son',
#  'dolly parton': 'kick',
#  'don henley': 'love',
#  'don mclean': 'atmosphere',
#  'don moen': 'aa',
#  'donna summer': 'cryin',
#  'doobie brothers': 'way',
#  'doors': 'lost',
#  'doris day': 'could',
#  'drake': 'hundred',
#  'dream theater': 'majesty',
#  'dusty springfield': 'dilly',
#  'eagles': 'alone',
#  'ed sheeran': 'words',
#  'eddie cochran': 'door',
#  'electric light orchestra': 'alone',
#  'ella fitzgerald': 'believe',
#  'ellie goulding': 'go',
#  'elton john': 'shoes',
#  'elvis costello': 'lifelike',
#  'elvis presley': 'know',
#  'eminem': 'dead',
#  'emmylou harris': 'dream',
#  'engelbert humperdinck': 'theres',
#  'enigma': 'asking',
#  'enrique iglesias': 'aa',
#  'enya': 'child',
#  'eppu normaali': 'aa',
#  'erasure': 'sollst',
#  'eric clapton': 'found',
#  'erik santos': 'inside',
#  'etta james': 'head',
#  'europe': 'true',
#  'eurythmics': 'fun',
#  'evanescence': 'escape',
#  'everclear': 'wonderful',
#  'everlast': 'everlasting',
#  'exo': 'ttarawa',
#  'exo-k': 'overdose',
#  'extreme': 'blue',
#  'fabolous': 'really',
#  'face to face': 'right',
#  'faces': 'rude',
#  'faith hill': 'away',
#  'faith no more': 'go',
#  'falco': 'alone',
#  'fall out boy': 'matters',
#  'fastball': 'time',
#  'fatboy slim': 'tell',
#  'fifth harmony': 'christmas',
#  'fiona apple': 'breaking',
#  'fleetwood mac': 'ooh',
#  'flo-rida': 'prowl',
#  'foo fighters': 'ive',
#  'foreigner': 'way',
#  'frank sinatra': 'arms',
#  'frank zappa': 'nowhere',
#  'frankie goes to hollywood': 'love',
#  'frankie laine': 'one',
#  'frankie valli': 'ready',
#  'freddie aguilar': 'maloko',
#  'freddie king': 'love',
#  'free': 'yeah',
#  'freestyle': 'behind',
#  'fun.': 'back',
#  'garth brooks': 'move',
#  'gary numan': 'believe',
#  'gary valenciano': 'call',
#  'genesis': 'leave',
#  'george formby': 'everything',
#  'george harrison': 'forever',
#  'george jones': 'love',
#  'george michael': 'love',
#  'george strait': 'male',
#  'gino vannelli': 'lights',
#  'gipsy kings': 'para',
#  'glee': 'drum',
#  'glen campbell': 'time',
#  'gloria estefan': 'love',
#  'gloria gaynor': 'need',
#  'gmb': 'menyenangkanmu',
#  'gordon lightfoot': 'dee',
#  'grand funk railroad': 'mistreater',
#  'grateful dead': 'world',
#  'grease': 'heed',
#  'great big sea': 'get',
#  'green day': 'pop',
#  'gucci mane': 'aa',
#  'guided by voices': 'tonight',
#  "guns n' roses": 'crazy',
#  'halloween': 'alakazamakazoo',
#  'hank snow': 'moanin',
#  'hank williams': 'leave',
#  'hank williams jr.': 'tonight',
#  'hanson': 'dying',
#  'happy mondays': 'back',
#  'harry belafonte': 'belly',
#  'harry connick, jr.': 'get',
#  'heart': 'gun',
#  'helloween': 'grows',
#  'high school musical': 'yeah',
#  'hillsong': 'fame',
#  'hillsong united': 'aa',
#  'him': 'heart',
#  'hollies': 'shines',
#  'hooverphonic': 'go',
#  'horrible histories': 'shakespeare',
#  'housemartins': 'back',
#  'howard jones': 'mary',
#  'human league': 'crashing',
#  'ian hunter': 'repeat',
#  'ice cube': 'kick',
#  'idina menzel': 'begin',
#  'iggy pop': 'got',
#  'il divo': 'door',
#  'imagine dragons': 'shake',
#  'imago': 'la',
#  'imperials': 'name',
#  'incognito': 'true',
#  'incubus': 'made',
#  'independence day': 'begin',
#  'indiana bible college': 'lord',
#  'indigo girls': 'clean',
#  'ingrid michaelson': 'good',
#  'inna': 'tonight',
#  'insane clown posse': 'freeek',
#  'inside out': 'air',
#  'inxs': 'fed',
#  'iron butterfly': 'win',
#  'iron maiden': 'away',
#  'irving berlin': 'day',
#  'isley brothers': 'yeah',
#  'israel': 'nobody',
#  'israel houghton': 'repeats',
#  'iwan fals': 'tardjana',
#  'j cole': 'work',
#  'jackson browne': 'justice',
#  'james taylor': 'man',
#  'janis joplin': 'lord',
#  'jason mraz': 'sign',
#  'jennifer lopez': 'song',
#  'jim croce': 'slim',
#  'jimi hendrix': 'floatin',
#  'jimmy buffett': 'time',
#  'john denver': 'fly',
#  'john legend': 'hallelujah',
#  'john martyn': 'begin',
#  'john mcdermott': 'athenry',
#  'john mellencamp': 'life',
#  'john prine': 'anymore',
#  'john waite': 'bottle',
#  'johnny cash': 'back',
#  'joni mitchell': 'love',
#  'jose mari chan': 'tell',
#  'joseph and the amazing technicolor dreamcoat': 'days',
#  'josh groban': 'ever',
#  'journey': 'love',
#  'joy division': 'good',
#  'judas priest': 'comin',
#  'judds': 'board',
#  'judy garland': 'heart',
#  'justin bieber': 'load',
#  'justin timberlake': 'heart',
#  'kanye west': 'glory',
#  'kari jobe': 'enough',
#  'kate bush': 'sugar',
#  'katy perry': 'miss',
#  'keith green': 'heart',
#  'keith urban': 'youre',
#  'kelly clarkson': 'yah',
#  'kelly family': 'confidence',
#  'kenny chesney': 'wasnt',
#  'kenny loggins': 'oww',
#  'kenny rogers': 'love',
#  'kid rock': 'potatoes',
#  'kim wilde': 'free',
#  'king crimson': 'air',
#  'king diamond': 'friend',
#  'kinks': 'dream',
#  'kirk franklin': 'miles',
#  'kirsty maccoll': 'way',
#  'kiss': 'mercy',
#  'koes plus': 'fatimah',
#  'korn': 'fuck',
#  'kris kristofferson': 'always',
#  'kyla': 'without',
#  'kylie minogue': 'tears',
#  'lady gaga': 'without',
#  'lana del rey': 'make',
#  'lata mangeshkar': 'koi',
#  'lauryn hill': 'bad',
#  'lea salonga': 'place',
#  'leann rimes': 'ruined',
#  'lenny kravitz': 'tempting',
#  'leo sayer': 'darling',
#  'leonard cohen': 'way',
#  'les miserables': 'begin',
#  'lil wayne': 'thats',
#  'linda ronstadt': 'today',
#  'linkin park': 'want',
#  'lionel richie': 'yeah',
#  'little mix': 'star',
#  'little walter': 'time',
#  'll cool j': 'heart',
#  'lloyd cole': 'home',
#  'lorde': 'beat',
#  'loretta lynn': 'home',
#  'lou reed': 'wh',
#  'louis armstrong': 'top',
#  'louis jordan': 'jack',
#  'lucky dube': 'worry',
#  'luther vandross': 'one',
#  'lynyrd skynyrd': 'goes',
#  'madonna': 'funeral',
#  'manowar': 'ride',
#  'mariah carey': 'baby',
#  'marianne faithfull': 'home',
#  'marillion': 'away',
#  'marilyn manson': 'get',
#  'mark ronson': 'valerie',
#  'maroon 5': 'yeah',
#  'mary black': 'love',
#  'matt monro': 'got',
#  'matt redman': 'blessing',
#  'mazzy star': 'stars',
#  'mc hammer': 'oh',
#  'meat loaf': 'wrong',
#  'megadeth': 'youthanasia',
#  'men at work': 'night',
#  'metallica': 'yeah',
#  'michael bolton': 'would',
#  'michael buble': 'friend',
#  'michael jackson': 'everything',
#  'michael w. smith': 'given',
#  'migos': 'fucked',
#  'miley cyrus': 'day',
#  'misfits': 'belong',
#  'modern talking': 'made',
#  'moody blues': 'home',
#  'morrissey': 'forgive',
#  'mud': 'love',
#  'nat king cole': 'would',
#  'natalie cole': 'day',
#  'natalie grant': 'good',
#  'natalie imbruglia': 'want',
#  'nazareth': 'aint',
#  'ne-yo': 'yeah',
#  'neil diamond': 'hey',
#  'neil sedaka': 'singing',
#  'neil young': 'home',
#  'new order': 'piss',
#  'next to normal': 'alive',
#  'nick cave': 'blood',
#  'nick drake': 'voice',
#  'nickelback': 'yanking',
#  'nicki minaj': 'love',
#  'nightwish': 'hope',
#  'nina simone': 'believe',
#  'nine inch nails': 'want',
#  'nirvana': 'pain',
#  'nitty gritty dirt band': 'railroad',
#  'noa': 'love',
#  'nofx': 'believed',
#  'norah jones': 'get',
#  'notorious b.i.g.': 'tell',
#  'o-zone': 'day',
#  'o.a.r.': 'tonight',
#  'oasis': 'rapture',
#  'ocean colour scene': 'worse',
#  'offspring': 'lives',
#  'ofra haza': 'love',
#  'oingo boingo': 'oh',
#  "old 97's": 'heart',
#  'oliver': 'two',
#  'olivia newton-john': 'time',
#  'olly murs': 'love',
#  'omd': 'universal',
#  'one direction': 'world',
#  'onerepublic': 'wanted',
#  'opeth': 'last',
#  'orphaned land': 'sun',
#  'oscar hammerstein': 'alone',
#  'otis redding': 'baby',
#  'our lady peace': 'crying',
#  'out of eden': 'way',
#  'outkast': 'traps',
#  'overkill': 'wreck',
#  'owl city': 'tonight',
#  'ozzy osbourne': 'stomp',
#  'p!nk': 'aa',
#  'passenger': 'shouts',
#  'pat benatar': 'dreamland',
#  'patsy cline': 'stronger',
#  'patti smith': 'without',
#  'paul mccartney': 'song',
#  'paul simon': 'away',
#  'pearl jam': 'oh',
#  'perry como': 'impossible',
#  'pet shop boys': 'aaahhh',
#  'peter cetera': 'need',
#  'peter gabriel': 'shadow',
#  'peter tosh': 'eyes',
#  'pharrell williams': 'get',
#  'phil collins': 'mean',
#  'phineas and ferb': 'goin',
#  'phish': 'ebenezer',
#  'pink floyd': 'blow',
#  'pitbull': 'love',
#  'planetshakers': 'everything',
#  'pogues': 'tonight',
#  'point of grace': 'name',
#  'poison': 'yeah',
#  'pretenders': 'changed',
#  'primus': 'porcupine',
#  'prince': 'man',
#  'proclaimers': 'childhood',
#  'procol harum': 'go',
#  'puff daddy': 'bitch',
#  'q-tip': 'nothing',
#  'qntal': 'vergalt',
#  'quarashi': 'bone',
#  'quarterflash': 'city',
#  'quasi': 'mistake',
#  'queen': 'go',
#  'queen adreena': 'tock',
#  'queen latifah': 'ragga',
#  'queens of the stone age': 'know',
#  'queensryche': 'inside',
#  'quicksand': 'feel',
#  'quicksilver messenger service': 'okay',
#  'quiet riot': 'know',
#  'quietdrive': 'say',
#  'quincy jones': 'ooh',
#  'quincy punx': 'second',
#  'r. kelly': 'stickin',
#  'radiohead': 'yes',
#  'raffi': 'submarine',
#  'rage against the machine': 'yeah',
#  'rainbow': 'squeeze',
#  'rammstein': 'true',
#  'ramones': 'face',
#  'randy travis': 'gift',
#  'rascal flatts': 'leads',
#  'ray boltz': 'weedom',
#  'ray charles': 'day',
#  'reba mcentire': 'ill',
#  'red hot chili peppers': 'smell',
#  'regine velasquez': 'door',
#  'religious music': 'god',
#  'rem': 'aa',
#  'reo speedwagon': 'gone',
#  'richard marx': 'way',
#  'rick astley': 'love',
#  'rihanna': 'boy',
#  'robbie williams': 'tramp',
#  'rod stewart': 'yeah',
#  'rolling stones': 'eyes',
#  'roxette': 'turn',
#  'roxy music': 'make',
#  'roy orbison': 'woman',
#  'rush': 'thats',
#  'sam smith': 'stay',
#  'santana': 'memories',
#  'savage garden': 'tonight',
#  'scorpions': 'death',
#  'selah': 'raise',
#  'selena gomez': 'name',
#  'sia': 'smile',
#  'side a': 'praying',
#  'slayer': 'death',
#  'smiths': 'oh',
#  'snoop dogg': 'right',
#  'soundgarden': 'alone',
#  'soundtracks': 'ooo',
#  'spandau ballet': 'town',
#  'squeeze': 'moon',
#  'starship': 'easy',
#  'status quo': 'oh',
#  'steely dan': 'lose',
#  'steve miller band': 'time',
#  'stevie ray vaughan': 'storm',
#  'stevie wonder': 'whisper',
#  'sting': 'star',
#  'stone roses': 'eyes',
#  'stone temple pilots': 'burn',
#  'styx': 'man',
#  'sublime': 'work',
#  'supertramp': 'night',
#  'system of a down': 'multiply',
#  'talking heads': 'time',
#  'taylor swift': 'ah',
#  'tears for fears': 'knife',
#  'ten years after': 'old',
#  'the beatles': 'im',
#  'the broadways': 'sun',
#  'the jam': 'drum',
#  'the killers': 'goes',
#  'the monkees': 'came',
#  'the script': 'stays',
#  'the temptations': 'evrything',
#  'the weeknd': 'oh',
#  'the white stripes': 'pocket',
#  'thin lizzy': 'control',
#  'tiffany': 'ever',
#  'tim buckley': 'fly',
#  'tim mcgraw': 'shhwwwooo',
#  'tina turner': 'baby',
#  'tom jones': 'friend',
#  'tom lehrer': 'braun',
#  'tom t. hall': 'body',
#  'tom waits': 'home',
#  'tool': 'mind',
#  'tori amos': 'pedro',
#  'toto': 'game',
#  'townes van zandt': 'needed',
#  'tracy chapman': 'one',
#  'tragically hip': 'youre',
#  'train': 'ill',
#  'travis': 'apart',
#  'twenty one pilots': 'hello',
#  'u-kiss': 'stalker',
#  'u. d. o.': 'live',
#  'u2': 'oh',
#  'ub40': 'news',
#  'ufo': 'else',
#  'ugly kid joe': 'best',
#  "ultramagnetic mc's": 'go',
#  'ultravox': 'vienna',
#  'uncle kracker': 'go',
#  'uncle tupelo': 'weighs',
#  'underoath': 'wake',
#  'underworld': 'stay',
#  'unearth': 'back',
#  'ungu': 'ku',
#  'unkle': 'forgiven',
#  'unknown': 'law',
#  'unseen': 'hay',
#  'unwritten law': 'pick',
#  'uriah heep': 'begun',
#  'used': 'heart',
#  'usher': 'say',
#  'utada hikaru': 'oozora',
#  'utopia': 'touch',
#  'van der graaf generator': 'ended',
#  'van halen': 'lost',
#  'van morrison': 'underwear',
#  'vanessa williams': 'go',
#  'vangelis': 'blue',
#  'vanilla ice': 'repeat',
#  'various artists': 'begun',
#  'velvet underground': 'anyone',
#  'vengaboys': 'celebration',
#  'venom': 'fight',
#  'vera lynn': 'born',
#  'vertical horizon': 'never',
#  'veruca salt': 'save',
#  'verve': 'leaving',
#  'vince gill': 'town',
#  'violent femmes': 'living',
#  'virgin steele': 'babe',
#  'vonda shepard': 'steal',
#  'vybz kartel': 'alone',
#  'w.a.s.p.': 'xtc',
#  'walk the moon': 'oh',
#  'wanda jackson': 'way',
#  'wang chung': 'repeat',
#  'warren zevon': 'face',
#  'waterboys': 'party',
#  'waylon jennings': 'gone',
#  'ween': 'buddy',
#  'weezer': 'giving',
#  'weird al yankovic': 'heels',
#  'westlife': 'man',
#  'wet wet wet': 'yesterday',
#  'wham!': 'sight',
#  'whiskeytown': 'time',
#  'whitesnake': 'fine',
#  'whitney houston': 'man',
#  'who': 'hymie',
#  'widespread panic': 'fine',
#  'will smith': 'come',
#  'willie nelson': 'goodbye',
#  'wilson phillips': 'way',
#  'wilson pickett': 'fade',
#  'wishbone ash': 'give',
#  'within temptation': 'us',
#  'wiz khalifa': 'ooh',
#  'wu-tang clan': 'twice',
#  'wyclef jean': 'love',
#  'x': 'world',
#  'x japan': 'line',
#  'x-raided': 'aa',
#  'x-ray spex': 'tube',
#  'x-treme': 'mine',
#  'xandria': 'hearts',
#  'xavier naidoo': 'etc',
#  'xavier rudd': 'content',
#  'xentrix': 'within',
#  'xiu xiu': 'hello',
#  'xscape': 'yeah',
#  'xtc': 'hearts',
#  'xzibit': 'aa',
#  'yazoo': 'hear',
#  'yeah yeah yeahs': 'name',
#  'yelawolf': 'fresh',
#  'yello': 'air',
#  'yellowcard': 'understand',
#  'yeng constantino': 'pala',
#  'yes': 'things',
#  'yg': 'love',
#  'ying yang twins': 'water',
#  'yngwie malmsteen': 'sword',
#  'yo gotti': 'said',
#  'yo la tengo': 'waiting',
#  'yoko ono': 'ooh',
#  'yolanda adams': 'yeah',
#  'yonder mountain string band': 'coming',
#  'you am i': 'blind',
#  'young buck': 'bitch',
#  'young dro': 'aa',
#  'young jeezy': 'nigga',
#  'youngbloodz': 'big',
#  'youth of today': 'store',
#  'yukmouth': 'boy',
#  'yung joc': 'aa',
#  'yusuf islam': 'daaark',
#  'z-ro': 'war',
#  'zac brown band': 'time',
#  'zakk wylde': 'concern',
#  'zao': 'open',
#  'zayn malik': 'way',
#  'zazie': 'game',
#  'zebra': 'time',
#  'zebrahead': 'took',
#  'zed': 'much',
#  'zero 7': 'flame',
#  'zeromancer': 'dumb',
#  'ziggy marley': 'movements',
#  'zoe': 'aa',
#  'zoegirl': 'repeat',
#  'zornik': 'liked',
#  'zox': 'dry',
#  'zucchero': 'happens',
#  'zwan': 'less',
#  'zz top': 'swirl'}

# %%
import itertools

newDict = dict(itertools.islice(artist_most_frequent_words.items(), 10))
plt.figure(figsize=(10, 6))
plt.bar(newDict.keys(), newDict.values())
plt.xlabel('Artist')
plt.ylabel('Frequency of Most Common Word')
plt.title('Most Common Word for Each Artist')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
artist_most_frequent_words["'n sync"]
# Out:
# 'love'

# %%
artist_tfidf_most_frequent_word = {}
for artist, word in artist_most_frequent_words.items():
    word_index = tfidf_vectorizer.vocabulary_[word]
    artist_index = tmp[tmp['artist'] == artist].index[0]
    tfidf_score = tfidf_matrix[artist_index, word_index]
    artist_tfidf_most_frequent_word[artist] = tfidf_score

# %% [markdown]
# Sampling

# %%
df=df.sort_values(by='artist')
first_100_artists=df['artist'].unique()[:100]
df=df[df['artist'].isin(first_100_artists)]
df
# Out:
#              artist                                             lyrics
# 13347       'n sync  girl dont say that its over cause you are a pa...
# 44696       'n sync  would you be my girlfriend repeat x i like you...
# 44695       'n sync   gotta giddy up yeah n sync giddy up gotta gid...
# 44694       'n sync  forever young forever young forever young fore...
# 44693       'n sync  you know that i love you in every way you brin...
# ...             ...                                                ...
# 29951  dolly parton   bill owens like the morning sun his love move...
# 29947  dolly parton  aint no use to sit and wonder why babe it dont...
# 29946  dolly parton  im tempted my darlin to steal you away dont le...
# 29945  dolly parton   dolly parton our love affair is bitter sweet ...
# 29944  dolly parton  am i to face these lonely halls alone and when...
#
# [11418 rows x 2 columns]

# %%
df['artist_lyrics'] = df.apply(lambda row:  ''.join(row['artist'].split()) + ' ' +' '.join(row['lyrics'].split()[:-1]) , axis=1)

# %%
df.head()
#df['artist_first_word'] = df['artist'] + ' ' + df['lyrics'].str.split().str.get()
#df.head()
# Out:
#         artist                                             lyrics  \
# 13347  'n sync  girl dont say that its over cause you are a pa...
# 44696  'n sync  would you be my girlfriend repeat x i like you...
# 44695  'n sync   gotta giddy up yeah n sync giddy up gotta gid...
# 44694  'n sync  forever young forever young forever young fore...
# 44693  'n sync  you know that i love you in every way you brin...
#
#                                            artist_lyrics
# 13347  'nsync girl dont say that its over cause you a...
# 44696  'nsync would you be my girlfriend repeat x i l...
# 44695  'nsync gotta giddy up yeah n sync giddy up got...
# 44694  'nsync forever young forever young forever you...
# 44693  'nsync you know that i love you in every way y...

# %%
df['artist_lyrics'].get(0)
# Out:
# 'abba look at her face its a wonderful face and it means something special to me look at the way that she smiles when she sees me how lucky can one fellow be shes just my kind of girl she makes me feel fine who could ever believe that she could be mine shes just my kind of girl without her im blue and if she ever leaves me what could i do what could i do and when we go for a walk in the park and she holds me and squeezes my hand well go on walking for hours and talking about all the things that we plan shes just my kind of girl she makes me feel fine who could ever believe that she could be mine shes just my kind of girl without her im blue and if she ever leaves me what could i do what could i'

# %%
df['lyrics'].get(0)
# Out:
# 'look at her face its a wonderful face and it means something special to me look at the way that she smiles when she sees me how lucky can one fellow be shes just my kind of girl she makes me feel fine who could ever believe that she could be mine shes just my kind of girl without her im blue and if she ever leaves me what could i do what could i do and when we go for a walk in the park and she holds me and squeezes my hand well go on walking for hours and talking about all the things that we plan shes just my kind of girl she makes me feel fine who could ever believe that she could be mine shes just my kind of girl without her im blue and if she ever leaves me what could i do what could i do '

# %%
df['song_Length'] = df['lyrics'].str.len()
df['artist_lyrics_len'] = df['artist_lyrics'].str.len()
df.head()
# Out:
#         artist                                             lyrics  \
# 13347  'n sync  girl dont say that its over cause you are a pa...
# 44696  'n sync  would you be my girlfriend repeat x i like you...
# 44695  'n sync   gotta giddy up yeah n sync giddy up gotta gid...
# 44694  'n sync  forever young forever young forever young fore...
# 44693  'n sync  you know that i love you in every way you brin...
#
#                                            artist_lyrics  song_Length  \
# 13347  'nsync girl dont say that its over cause you a...         1849
# 44696  'nsync would you be my girlfriend repeat x i l...         1801
# 44695  'nsync gotta giddy up yeah n sync giddy up got...         1414
# 44694  'nsync forever young forever young forever you...         1453
# 44693  'nsync you know that i love you in every way y...         1104
#
#        artist_lyrics_len
# 13347               1851
# 44696               1796
# 44695               1412
# 44694               1453
# 44693               1100

# %%
df['lyrics'] = df['lyrics'].apply(lambda x: x.split()[-1])
df.head()
# Out:
#         artist      lyrics                                      artist_lyrics  \
# 13347  'n sync         you  'nsync girl dont say that its over cause you a...
# 44696  'n sync  girlfriend  'nsync would you be my girlfriend repeat x i l...
# 44695  'n sync          up  'nsync gotta giddy up yeah n sync giddy up got...
# 44694  'n sync       young  'nsync forever young forever young forever you...
# 44693  'n sync       heart  'nsync you know that i love you in every way y...
#
#        song_Length  artist_lyrics_len
# 13347         1849               1851
# 44696         1801               1796
# 44695         1414               1412
# 44694         1453               1453
# 44693         1104               1100

# %%
grouped= df.groupby(['artist'])['song_Length'].mean().reset_index().head(10)
grouped=grouped.sort_values('song_Length',ascending=False)
grouped.plot.bar(x="artist", y="song_Length",title='Avg Song Length Per Artist', ylabel='Avg Length',
         xlabel='Artists',)
plt.show()

# %%
plt.hist(df['song_Length'].values,range=(0,6000))
plt.show()

# %%
df['song_Length'].max()
# Out:
# 3668

# %%
df= df.drop(['artist'], axis=1)
df.head()
# Out:
#            lyrics                                      artist_lyrics  \
# 13347         you  'nsync girl dont say that its over cause you a...
# 44696  girlfriend  'nsync would you be my girlfriend repeat x i l...
# 44695          up  'nsync gotta giddy up yeah n sync giddy up got...
# 44694       young  'nsync forever young forever young forever you...
# 44693       heart  'nsync you know that i love you in every way y...
#
#        song_Length  artist_lyrics_len
# 13347         1849               1851
# 44696         1801               1796
# 44695         1414               1412
# 44694         1453               1453
# 44693         1104               1100

# %%
df.shape
# Out:
# (11418, 4)

# %%
df[df['song_Length'] >2500].count()
# Out:
# lyrics               86
# artist_lyrics        86
# song_Length          86
# artist_lyrics_len    86
# dtype: int64

# %%
df=df[df['song_Length']<=1500]

# %%
df['artist_lyrics_len'].max()
# Out:
# 1511

# %%
plt.hist(df['artist_lyrics_len'].values,range=(0,4000))
plt.show()

# %%
df['artist_lyrics_len'].count()
# Out:
# 10070

# %%
df[df['artist_lyrics_len'] >1500].count()
# Out:
# lyrics               25
# artist_lyrics        25
# song_Length          25
# artist_lyrics_len    25
# dtype: int64

# %%
df=df[df['artist_lyrics_len']<=1500]

# %%
df.shape
# Out:
# (10045, 4)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
terms = tf.ragged.constant(df["lyrics"].values)

# %%
unique_values = tf.unique(terms).y
unique_count = tf.size(unique_values)
print(f"Number of unique values: {unique_count}")
# Out:
# Number of unique values: 2243

# %%
lookup = tf.keras.layers.StringLookup(output_mode="one_hot", max_tokens=None)
lookup.adapt(terms)
vocab = lookup.get_vocabulary()

# %%
def get_word_from_probability(probabilities, vocab):

  max_index = np.argmax(probabilities)
  word = vocab[max_index]

  return word

# %% [markdown]
# Splitting data

# %%
from sklearn.model_selection import train_test_split
train_df,test_df=train_test_split(df,test_size=0.2,random_state=42)

# %%
X_train = train_df['artist_lyrics']
Y_train = train_df['lyrics']
X_test = test_df['artist_lyrics']
Y_test = test_df['lyrics']

# %%
labels = tf.ragged.constant(train_df['lyrics'].values)
label_binarized = lookup(labels).numpy()

# %%
labels_val = tf.ragged.constant(test_df['lyrics'].values)
label_binarized_val = lookup(labels_val).numpy()

# %%
label_binarized_val.shape
# Out:
# (2009, 2244)

# %%
X_test.shape
# Out:
# (2009,)

# %%
X_train[:3]
# Out:
# 26001    bobseger i wasnt born lookin back i cant tell ...
# 28612    danfogelberg joy at the start fear in the jour...
# 23311    alanparsonsproject when you were standing in t...
# Name: artist_lyrics, dtype: object

# %% [markdown]
# Model

# %%
embedding_dim = 64
units = 128
trunc_type='post'
padding_type='post'
max_length=1500

# %%
tokenizer =Tokenizer(num_words=None,#By default the value of num_words is none  best value is the vocab_size
                      filters='!"$%&()*,-./:;<=>?@[\\]^_`{|}~\t\n', #filter the text from punctuation we kept # and + for C# and C++
                      lower=True,
                      split=" ",#if you split with , or something else then this will be your splitter
                      char_level=False, #tokenization as char level or word level
                      oov_token=None) #what to replace an oov word with during training validation or testing

# %%
tokenizer.fit_on_texts(train_df['artist_lyrics'].values)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'i': 2,
#  'you': 3,
#  'to': 4,
#  'and': 5,
#  'a': 6,
#  'me': 7,
#  'in': 8,
#  'my': 9,
#  'of': 10,
#  'it': 11,
#  'your': 12,
#  'that': 13,
#  'on': 14,
#  'love': 15,
#  'all': 16,
#  'be': 17,
#  'im': 18,
#  'is': 19,
#  'for': 20,
#  'so': 21,
#  'dont': 22,
#  'but': 23,
#  'its': 24,
#  'just': 25,
#  'know': 26,
#  'we': 27,
#  'no': 28,
#  'with': 29,
#  'when': 30,
#  'oh': 31,
#  'like': 32,
#  'can': 33,
#  'this': 34,
#  'if': 35,
#  'do': 36,
#  'what': 37,
#  'now': 38,
#  'got': 39,
#  'up': 40,
#  'time': 41,
#  'go': 42,
#  'youre': 43,
#  'was': 44,
#  'one': 45,
#  'down': 46,
#  'will': 47,
#  'are': 48,
#  'out': 49,
#  'have': 50,
#  'never': 51,
#  'want': 52,
#  'see': 53,
#  'baby': 54,
#  'get': 55,
#  'she': 56,
#  'cant': 57,
#  'come': 58,
#  'say': 59,
#  'they': 60,
#  'he': 61,
#  'way': 62,
#  'not': 63,
#  'as': 64,
#  'ill': 65,
#  'let': 66,
#  'from': 67,
#  'there': 68,
#  'at': 69,
#  'take': 70,
#  'heart': 71,
#  'were': 72,
#  'well': 73,
#  'away': 74,
#  'her': 75,
#  'ive': 76,
#  'make': 77,
#  'night': 78,
#  'how': 79,
#  'yeah': 80,
#  'gonna': 81,
#  'life': 82,
#  'day': 83,
#  'cause': 84,
#  'here': 85,
#  'been': 86,
#  'back': 87,
#  'could': 88,
#  'more': 89,
#  'need': 90,
#  'feel': 91,
#  'theres': 92,
#  'little': 93,
#  'by': 94,
#  'where': 95,
#  'right': 96,
#  'through': 97,
#  'too': 98,
#  'world': 99,
#  'only': 100,
#  'tell': 101,
#  'give': 102,
#  'man': 103,
#  'good': 104,
#  'or': 105,
#  'his': 106,
#  'eyes': 107,
#  'again': 108,
#  'always': 109,
#  'every': 110,
#  'long': 111,
#  'our': 112,
#  'wont': 113,
#  'then': 114,
#  'some': 115,
#  'aint': 116,
#  'thats': 117,
#  'think': 118,
#  'why': 119,
#  'would': 120,
#  'la': 121,
#  'had': 122,
#  'find': 123,
#  'still': 124,
#  'home': 125,
#  'who': 126,
#  'around': 127,
#  'over': 128,
#  'look': 129,
#  'girl': 130,
#  'said': 131,
#  'us': 132,
#  'about': 133,
#  'ever': 134,
#  'am': 135,
#  'keep': 136,
#  'shes': 137,
#  'mind': 138,
#  'an': 139,
#  'hear': 140,
#  'much': 141,
#  'youll': 142,
#  'things': 143,
#  'hold': 144,
#  'him': 145,
#  'gone': 146,
#  'alone': 147,
#  'old': 148,
#  'id': 149,
#  'nothing': 150,
#  'hey': 151,
#  'believe': 152,
#  'better': 153,
#  'before': 154,
#  'youve': 155,
#  'really': 156,
#  'tonight': 157,
#  'christmas': 158,
#  'light': 159,
#  'into': 160,
#  'live': 161,
#  'than': 162,
#  'them': 163,
#  'new': 164,
#  'has': 165,
#  'dream': 166,
#  'try': 167,
#  'true': 168,
#  'hes': 169,
#  'everything': 170,
#  'made': 171,
#  'thing': 172,
#  'inside': 173,
#  'run': 174,
#  'stay': 175,
#  'leave': 176,
#  'something': 177,
#  'turn': 178,
#  'sun': 179,
#  'face': 180,
#  'last': 181,
#  'people': 182,
#  'blue': 183,
#  'another': 184,
#  'without': 185,
#  'did': 186,
#  'wanna': 187,
#  'must': 188,
#  'mine': 189,
#  'left': 190,
#  'yes': 191,
#  'going': 192,
#  'sweet': 193,
#  'someone': 194,
#  'please': 195,
#  'call': 196,
#  'cry': 197,
#  'should': 198,
#  'head': 199,
#  'hard': 200,
#  'gotta': 201,
#  'place': 202,
#  'wrong': 203,
#  'walk': 204,
#  'fall': 205,
#  'their': 206,
#  'show': 207,
#  'hand': 208,
#  'forever': 209,
#  'even': 210,
#  'comes': 211,
#  'sing': 212,
#  'free': 213,
#  'remember': 214,
#  'stop': 215,
#  'those': 216,
#  'lost': 217,
#  'far': 218,
#  'dreams': 219,
#  'ooh': 220,
#  'days': 221,
#  'feeling': 222,
#  'put': 223,
#  'together': 224,
#  'same': 225,
#  'song': 226,
#  'off': 227,
#  'maybe': 228,
#  'end': 229,
#  'these': 230,
#  'care': 231,
#  'two': 232,
#  'boy': 233,
#  'may': 234,
#  'play': 235,
#  'sky': 236,
#  'lonely': 237,
#  'thought': 238,
#  'lets': 239,
#  'woman': 240,
#  'while': 241,
#  'change': 242,
#  'own': 243,
#  'fire': 244,
#  'found': 245,
#  'kiss': 246,
#  'looking': 247,
#  'big': 248,
#  'once': 249,
#  'didnt': 250,
#  'many': 251,
#  'lord': 252,
#  'rain': 253,
#  'morning': 254,
#  'god': 255,
#  'ya': 256,
#  'other': 257,
#  'road': 258,
#  'soul': 259,
#  'round': 260,
#  'high': 261,
#  'close': 262,
#  'waiting': 263,
#  'enough': 264,
#  'friend': 265,
#  'hope': 266,
#  'stand': 267,
#  'name': 268,
#  'knew': 269,
#  'help': 270,
#  'words': 271,
#  'door': 272,
#  'each': 273,
#  'dance': 274,
#  'might': 275,
#  'myself': 276,
#  'cold': 277,
#  'done': 278,
#  'pain': 279,
#  'wish': 280,
#  'happy': 281,
#  'best': 282,
#  'town': 283,
#  'till': 284,
#  'bring': 285,
#  'coming': 286,
#  'start': 287,
#  'wait': 288,
#  'sure': 289,
#  'years': 290,
#  'though': 291,
#  'goodbye': 292,
#  'die': 293,
#  'today': 294,
#  'sometimes': 295,
#  'ah': 296,
#  'touch': 297,
#  'living': 298,
#  'whats': 299,
#  'arms': 300,
#  'hell': 301,
#  'side': 302,
#  'came': 303,
#  'lose': 304,
#  'bad': 305,
#  'tears': 306,
#  'smile': 307,
#  'heaven': 308,
#  'after': 309,
#  'times': 310,
#  'na': 311,
#  'goes': 312,
#  'talk': 313,
#  'friends': 314,
#  'da': 315,
#  'theyre': 316,
#  'used': 317,
#  'break': 318,
#  'fly': 319,
#  'any': 320,
#  'knows': 321,
#  'easy': 322,
#  'behind': 323,
#  'makes': 324,
#  'first': 325,
#  'real': 326,
#  'rock': 327,
#  'wind': 328,
#  'fool': 329,
#  'seen': 330,
#  'kind': 331,
#  'crazy': 332,
#  'deep': 333,
#  'forget': 334,
#  'told': 335,
#  'sleep': 336,
#  'understand': 337,
#  'took': 338,
#  'young': 339,
#  'line': 340,
#  'born': 341,
#  'saw': 342,
#  'seems': 343,
#  'money': 344,
#  'watch': 345,
#  'along': 346,
#  'because': 347,
#  'heard': 348,
#  'open': 349,
#  'weve': 350,
#  'hands': 351,
#  'moon': 352,
#  'matter': 353,
#  'strong': 354,
#  'else': 355,
#  'music': 356,
#  'honey': 357,
#  'nobody': 358,
#  'o': 359,
#  'ride': 360,
#  'soon': 361,
#  'alright': 362,
#  'tomorrow': 363,
#  'miss': 364,
#  'chance': 365,
#  'until': 366,
#  'wonder': 367,
#  'hearts': 368,
#  'broken': 369,
#  'dark': 370,
#  'move': 371,
#  'late': 372,
#  'child': 373,
#  'children': 374,
#  'very': 375,
#  'somebody': 376,
#  'sea': 377,
#  'street': 378,
#  'mean': 379,
#  'yourself': 380,
#  'stars': 381,
#  'everybody': 382,
#  'river': 383,
#  'loves': 384,
#  'went': 385,
#  'youd': 386,
#  'part': 387,
#  'hide': 388,
#  'lay': 389,
#  'fine': 390,
#  'lie': 391,
#  'falling': 392,
#  'pretty': 393,
#  'moment': 394,
#  'white': 395,
#  'work': 396,
#  'under': 397,
#  'such': 398,
#  'listen': 399,
#  'ground': 400,
#  'couldnt': 401,
#  'roll': 402,
#  'lights': 403,
#  'does': 404,
#  'gave': 405,
#  'girls': 406,
#  'shine': 407,
#  'upon': 408,
#  'guess': 409,
#  'above': 410,
#  'anything': 411,
#  'reason': 412,
#  'lies': 413,
#  'game': 414,
#  'hurt': 415,
#  'dear': 416,
#  'black': 417,
#  'eye': 418,
#  'red': 419,
#  'loved': 420,
#  'ready': 421,
#  'tried': 422,
#  'trying': 423,
#  'land': 424,
#  'room': 425,
#  'getting': 426,
#  'feet': 427,
#  'walking': 428,
#  'ask': 429,
#  'sad': 430,
#  'lot': 431,
#  'dead': 432,
#  'set': 433,
#  'uh': 434,
#  'full': 435,
#  'wanted': 436,
#  'thinking': 437,
#  'star': 438,
#  'fun': 439,
#  'whole': 440,
#  'apart': 441,
#  'gets': 442,
#  'past': 443,
#  'alive': 444,
#  'darling': 445,
#  'boys': 446,
#  'bright': 447,
#  'standing': 448,
#  'since': 449,
#  'somewhere': 450,
#  'bye': 451,
#  'water': 452,
#  'truth': 453,
#  'takes': 454,
#  'beautiful': 455,
#  'doesnt': 456,
#  'em': 457,
#  'running': 458,
#  'word': 459,
#  'fast': 460,
#  'says': 461,
#  'goin': 462,
#  'near': 463,
#  'bed': 464,
#  'seem': 465,
#  'air': 466,
#  'house': 467,
#  'city': 468,
#  'lady': 469,
#  'mama': 470,
#  'feels': 471,
#  'dancing': 472,
#  'babe': 473,
#  'tree': 474,
#  'til': 475,
#  'next': 476,
#  'loving': 477,
#  'everyone': 478,
#  'nights': 479,
#  'meet': 480,
#  'sound': 481,
#  'burning': 482,
#  'snow': 483,
#  'train': 484,
#  'learn': 485,
#  'king': 486,
#  'save': 487,
#  'afraid': 488,
#  'body': 489,
#  'warm': 490,
#  'between': 491,
#  'lovin': 492,
#  'hello': 493,
#  'wouldnt': 494,
#  'year': 495,
#  'angels': 496,
#  'hot': 497,
#  'keeps': 498,
#  'peace': 499,
#  'anymore': 500,
#  'earth': 501,
#  'fight': 502,
#  'making': 503,
#  'shake': 504,
#  'felt': 505,
#  'bout': 506,
#  'wake': 507,
#  'whos': 508,
#  'men': 509,
#  'lover': 510,
#  'being': 511,
#  'share': 512,
#  'wants': 513,
#  'beat': 514,
#  'lovers': 515,
#  'across': 516,
#  'use': 517,
#  'pay': 518,
#  'tired': 519,
#  'lips': 520,
#  'wild': 521,
#  'follow': 522,
#  'rest': 523,
#  'calling': 524,
#  'hair': 525,
#  'repeat': 526,
#  'turned': 527,
#  'mother': 528,
#  'summer': 529,
#  'laugh': 530,
#  'blues': 531,
#  'pray': 532,
#  'lives': 533,
#  'slow': 534,
#  'met': 535,
#  'low': 536,
#  'clear': 537,
#  'control': 538,
#  'fear': 539,
#  'comin': 540,
#  'someday': 541,
#  'hate': 542,
#  'tight': 543,
#  'known': 544,
#  'merry': 545,
#  'crying': 546,
#  'shell': 547,
#  'bells': 548,
#  'ring': 549,
#  'everywhere': 550,
#  'blind': 551,
#  'watching': 552,
#  'isnt': 553,
#  'floor': 554,
#  'joy': 555,
#  'angel': 556,
#  'reach': 557,
#  'x': 558,
#  'drive': 559,
#  'holding': 560,
#  'jesus': 561,
#  'cool': 562,
#  'bit': 563,
#  'promise': 564,
#  'grow': 565,
#  'looked': 566,
#  'ones': 567,
#  'worry': 568,
#  'faith': 569,
#  'sit': 570,
#  'pum': 571,
#  'looks': 572,
#  'needs': 573,
#  'three': 574,
#  'feelin': 575,
#  'empty': 576,
#  'lead': 577,
#  'yet': 578,
#  'lookin': 579,
#  'send': 580,
#  'both': 581,
#  'voice': 582,
#  'shining': 583,
#  'blood': 584,
#  'carry': 585,
#  'knees': 586,
#  'wall': 587,
#  'meant': 588,
#  'burn': 589,
#  'throw': 590,
#  'wings': 591,
#  'spend': 592,
#  'singing': 593,
#  'hit': 594,
#  'sorry': 595,
#  'lucky': 596,
#  'memories': 597,
#  'santa': 598,
#  'n': 599,
#  'answer': 600,
#  'shame': 601,
#  'read': 602,
#  'leaving': 603,
#  'pass': 604,
#  'most': 605,
#  'story': 606,
#  'america': 607,
#  'nice': 608,
#  'outside': 609,
#  'great': 610,
#  'fell': 611,
#  'window': 612,
#  'wed': 613,
#  'different': 614,
#  'whoa': 615,
#  'oo': 616,
#  'nowhere': 617,
#  'higher': 618,
#  'top': 619,
#  'catch': 620,
#  'belong': 621,
#  'car': 622,
#  'daddy': 623,
#  'songs': 624,
#  'mr': 625,
#  'strange': 626,
#  'darlin': 627,
#  'saying': 628,
#  'future': 629,
#  'cross': 630,
#  'hang': 631,
#  'gun': 632,
#  'yours': 633,
#  'which': 634,
#  'nothin': 635,
#  'sight': 636,
#  'death': 637,
#  'doing': 638,
#  'gold': 639,
#  'dreaming': 640,
#  'worth': 641,
#  'started': 642,
#  'blow': 643,
#  'caught': 644,
#  'yesterday': 645,
#  'dog': 646,
#  'rather': 647,
#  'somehow': 648,
#  'drink': 649,
#  'finally': 650,
#  'talking': 651,
#  'anyone': 652,
#  'walked': 653,
#  'step': 654,
#  'magic': 655,
#  'power': 656,
#  'buy': 657,
#  'country': 658,
#  'stone': 659,
#  'beside': 660,
#  'fill': 661,
#  'son': 662,
#  'thousand': 663,
#  'giving': 664,
#  'darkness': 665,
#  'rise': 666,
#  'mountain': 667,
#  'green': 668,
#  'glory': 669,
#  'called': 670,
#  'midnight': 671,
#  'ways': 672,
#  'anyway': 673,
#  'playing': 674,
#  'theyll': 675,
#  'wasnt': 676,
#  'glad': 677,
#  'father': 678,
#  'bound': 679,
#  'phone': 680,
#  'perfect': 681,
#  'trees': 682,
#  'everyday': 683,
#  'poor': 684,
#  'tear': 685,
#  'straight': 686,
#  'shoes': 687,
#  'turning': 688,
#  'breath': 689,
#  'war': 690,
#  'taking': 691,
#  'million': 692,
#  'silver': 693,
#  'trust': 694,
#  'shadows': 695,
#  'tryin': 696,
#  'almost': 697,
#  'dry': 698,
#  'miles': 699,
#  'win': 700,
#  'closer': 701,
#  'knock': 702,
#  'trouble': 703,
#  'small': 704,
#  'doubt': 705,
#  'kill': 706,
#  'pull': 707,
#  'golden': 708,
#  'dying': 709,
#  'ago': 710,
#  'blame': 711,
#  'skies': 712,
#  'cut': 713,
#  'wear': 714,
#  'holy': 715,
#  'four': 716,
#  'treat': 717,
#  'half': 718,
#  'funny': 719,
#  'knowing': 720,
#  'streets': 721,
#  'sorrow': 722,
#  'eat': 723,
#  'cannot': 724,
#  'gettin': 725,
#  'party': 726,
#  'women': 727,
#  'shed': 728,
#  'wide': 729,
#  'telling': 730,
#  'memory': 731,
#  'whatever': 732,
#  'pride': 733,
#  'ha': 734,
#  'desire': 735,
#  'everybodys': 736,
#  'write': 737,
#  'school': 738,
#  'picture': 739,
#  'ocean': 740,
#  'five': 741,
#  'tender': 742,
#  'livin': 743,
#  'shot': 744,
#  'held': 745,
#  'shall': 746,
#  'pick': 747,
#  'cryin': 748,
#  'mercy': 749,
#  'guy': 750,
#  'hours': 751,
#  'yea': 752,
#  'feelings': 753,
#  'radio': 754,
#  'taste': 755,
#  'skin': 756,
#  'bar': 757,
#  'sunshine': 758,
#  'within': 759,
#  'moving': 760,
#  'weather': 761,
#  'filled': 762,
#  'speak': 763,
#  'luck': 764,
#  'breaking': 765,
#  'middle': 766,
#  'sand': 767,
#  'second': 768,
#  'special': 769,
#  'walls': 770,
#  'evening': 771,
#  'queen': 772,
#  'brother': 773,
#  'mirror': 774,
#  'played': 775,
#  'count': 776,
#  'winter': 777,
#  'others': 778,
#  'lovely': 779,
#  'learned': 780,
#  'grace': 781,
#  'hour': 782,
#  'clouds': 783,
#  'thinkin': 784,
#  'gimme': 785,
#  'longer': 786,
#  'broke': 787,
#  'died': 788,
#  'wonderful': 789,
#  'simple': 790,
#  'fade': 791,
#  'paradise': 792,
#  'corner': 793,
#  'walkin': 794,
#  'shadow': 795,
#  'number': 796,
#  'thoughts': 797,
#  'losing': 798,
#  'anywhere': 799,
#  'single': 800,
#  'news': 801,
#  'cried': 802,
#  'beyond': 803,
#  'leaves': 804,
#  'taken': 805,
#  'few': 806,
#  'wine': 807,
#  'ten': 808,
#  'runnin': 809,
#  'drop': 810,
#  'turns': 811,
#  'hurry': 812,
#  'bridge': 813,
#  'given': 814,
#  'choose': 815,
#  'thank': 816,
#  'doctor': 817,
#  'moonlight': 818,
#  'de': 819,
#  'scream': 820,
#  'hurts': 821,
#  'needed': 822,
#  'shout': 823,
#  'alabama': 824,
#  'quite': 825,
#  'ohh': 826,
#  'return': 827,
#  'dawn': 828,
#  'thrill': 829,
#  'breathe': 830,
#  'hanging': 831,
#  'begin': 832,
#  'missing': 833,
#  'sign': 834,
#  'shut': 835,
#  'freedom': 836,
#  'rolling': 837,
#  'fingers': 838,
#  'bop': 839,
#  'dirty': 840,
#  'ho': 841,
#  'become': 842,
#  'searching': 843,
#  'brings': 844,
#  'flame': 845,
#  'sin': 846,
#  'lying': 847,
#  'stranger': 848,
#  'secret': 849,
#  'edge': 850,
#  'pretend': 851,
#  'sick': 852,
#  'storm': 853,
#  'surprise': 854,
#  'guitar': 855,
#  'band': 856,
#  'realize': 857,
#  'fever': 858,
#  'highway': 859,
#  'front': 860,
#  'heat': 861,
#  'slowly': 862,
#  'rhythm': 863,
#  'chicago': 864,
#  'loud': 865,
#  'book': 866,
#  'sail': 867,
#  'waste': 868,
#  'swear': 869,
#  'birds': 870,
#  'kept': 871,
#  's': 872,
#  'ahead': 873,
#  'early': 874,
#  'brought': 875,
#  'whisper': 876,
#  'sitting': 877,
#  'mad': 878,
#  'crime': 879,
#  'mystery': 880,
#  'therell': 881,
#  'wherever': 882,
#  'sleeping': 883,
#  'stood': 884,
#  'christ': 885,
#  'hill': 886,
#  'thee': 887,
#  'flowers': 888,
#  'heres': 889,
#  'deeppurple': 890,
#  'space': 891,
#  'faces': 892,
#  'against': 893,
#  'cher': 894,
#  'ran': 895,
#  'damn': 896,
#  'steal': 897,
#  'chrisrea': 898,
#  'brown': 899,
#  'spirit': 900,
#  'fallin': 901,
#  'rose': 902,
#  'slip': 903,
#  'spent': 904,
#  'evil': 905,
#  'everythings': 906,
#  'working': 907,
#  'romance': 908,
#  'piece': 909,
#  'chakakhan': 910,
#  'happened': 911,
#  'havent': 912,
#  'bet': 913,
#  'hallelujah': 914,
#  'kisses': 915,
#  'folks': 916,
#  'means': 917,
#  'push': 918,
#  'bang': 919,
#  'climb': 920,
#  'cmon': 921,
#  'mans': 922,
#  'scared': 923,
#  'dressed': 924,
#  'kids': 925,
#  'laughing': 926,
#  'beneath': 927,
#  'heavy': 928,
#  'deanmartin': 929,
#  'hed': 930,
#  'lift': 931,
#  'passing': 932,
#  'dust': 933,
#  'growing': 934,
#  'minute': 935,
#  'changed': 936,
#  'miracle': 937,
#  'mister': 938,
#  'smoke': 939,
#  'point': 940,
#  'having': 941,
#  'letter': 942,
#  'roses': 943,
#  'brand': 944,
#  'cover': 945,
#  'brain': 946,
#  'ba': 947,
#  'clean': 948,
#  'doo': 949,
#  'doin': 950,
#  'ice': 951,
#  'less': 952,
#  'view': 953,
#  'lines': 954,
#  'ooo': 955,
#  'fate': 956,
#  'depechemode': 957,
#  'happiness': 958,
#  'cliffrichard': 959,
#  'flying': 960,
#  'd': 961,
#  'rockin': 962,
#  'starts': 963,
#  'fair': 964,
#  'distance': 965,
#  'clothes': 966,
#  'satisfied': 967,
#  'dress': 968,
#  'ball': 969,
#  'passed': 970,
#  'nobodys': 971,
#  'sunny': 972,
#  'case': 973,
#  'fit': 974,
#  'pa': 975,
#  'scene': 976,
#  'devil': 977,
#  'bird': 978,
#  'mouth': 979,
#  'happen': 980,
#  'key': 981,
#  'insane': 982,
#  'wheel': 983,
#  'law': 984,
#  'spell': 985,
#  'hungry': 986,
#  'welcome': 987,
#  'mary': 988,
#  'hole': 989,
#  'airsupply': 990,
#  'spring': 991,
#  'ghost': 992,
#  'surrender': 993,
#  'voices': 994,
#  'grown': 995,
#  'plan': 996,
#  'whenever': 997,
#  'bell': 998,
#  'silence': 999,
#  'awake': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index) + 1
X_train = tokenizer.texts_to_sequences(train_df['artist_lyrics'].values)
X_test = tokenizer.texts_to_sequences(test_df['artist_lyrics'].values)

# %%
vocab_size
# Out:
# 25477

# %%
X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

# %%
# tokenizer_lyrics =Tokenizer(num_words=None,
#                       filters='!"$%&()*,-./:;<=>?@[\\]^_`{|}~\t\n',
#                       lower=True,
#                       split=" ",
#                       char_level=False,
#                       oov_token=None)

# %%
# tokenizer_lyrics.fit_on_texts(train_df['lyrics'].values)
# Y_train = tokenizer_lyrics.texts_to_sequences(train_df['lyrics'].values)
# Y_test = tokenizer_lyrics.texts_to_sequences(test_df['lyrics'].values)

# %%
# Y_train = pad_sequences(Y_train, padding='post', maxlen=1500) #post so padding will be added at the end
# Y_test = pad_sequences(Y_test, padding='post', maxlen=1500)

# %%
# Y_train[0]

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
#     tf.keras.layers.GRU(units),
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.Dense(lookup.vocabulary_size(), activation='sigmoid')
# ])
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_shape=(max_length,)),
    tf.keras.layers.GRU(units),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(lookup.vocabulary_size(), activation='sigmoid')
])

# Set the training parameters
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
X_train.shape
# Out:
# (8036, 1500)

# %%
Y_train.shape
# Out:
# (8036,)

# %%
label_binarized.shape
# Out:
# (8036, 2244)

# %%
model.fit(X_train, label_binarized, epochs=10)
# Out:
# Epoch 1/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 428s 2s/step - accuracy: 0.0422 - loss: 6.9809
# Epoch 2/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 440s 2s/step - accuracy: 0.0618 - loss: 6.3182
# Epoch 3/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 445s 2s/step - accuracy: 0.0572 - loss: 6.2921
# Epoch 4/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 425s 2s/step - accuracy: 0.0541 - loss: 6.2883
# Epoch 5/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 440s 2s/step - accuracy: 0.0598 - loss: 6.2771
# Epoch 6/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 423s 2s/step - accuracy: 0.0614 - loss: 6.2796
# Epoch 7/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 448s 2s/step - accuracy: 0.0570 - loss: 6.3207
# Epoch 8/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 443s 2s/step - accuracy: 0.0559 - loss: 6.2723
# Epoch 9/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 421s 2s/step - accuracy: 0.0577 - loss: 6.2882
# Epoch 10/10
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 423s 2s/step - accuracy: 0.0542 - loss: 6.3093

# %%
oss, accuracy = model.evaluate(X_test, label_binarized_val)
print("Training Accuracy: {:.2f}%".format(accuracy * 100))
print('Accuracy: %f' % (accuracy*100))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 287ms/step - accuracy: 0.0693 - loss: 7.0914
# Training Accuracy: 5.72%
# Accuracy: 5.724241

# %%
test_df

# %%
testing_text= test_df['artist_lyrics'][25330]
actual_class=test_df['lyrics'][25330]
print(testing_text)
print(actual_class)
# Out:
# billieholiday like the beat beat beat of the tomtom when the jungle shadows fall like the tick tick tock of the stately clock as it stands against the wall like the drip drip drip of the raindrops when the summer showare is through so a voice within me keeps repeating you you you night and day you are the one only you beneath the moon and sun whether near me or far its no matter darling where you are i think of you night and day day and night why is it so that this longing for you follows wherever i go in the roaring traffics boom in the silence of my lonely room i think of you night and day night and day under the hide of me theres an oh such a hungry yearning burning inside of me and its torment wont be trough till you spent my life making love to you day and night night and day night and
# day

# %%
test_seq=tokenizer.texts_to_sequences([testing_text])
test_seq=pad_sequences(test_seq, padding='post', maxlen=max_length)
predictions=model.predict(test_seq)
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# array([[4.3432266e-04, 9.5861447e-01, 9.3913502e-01, ..., 5.1117603e-02,
#         5.8286503e-04, 3.6857996e-04]], dtype=float32)

# %%
get_word_from_probability(predictions,vocab)
# Out:
# 'you'
